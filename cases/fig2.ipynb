# %%
import sys 
sys.path.append("..") 

import matplotlib.pyplot as plt
import numpy as np
from tools import save_data, save_data_M, load_data, load_data_M

# %% [markdown]
# # 1D Hatano-Nelson (point gap)

# %%
name = "1D_Hatano_Nelson"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig2_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
J2s = np.linspace(0.001,2, len(v_list))
plt.figure(figsize=(3,3))
plt.plot(J2s, v_list,'-o')
plt.xticks([0, 1, 2],fontsize=20)
plt.yticks(range(1, len(group_number)+1),fontsize=20)
plt.xlim([-0.05, 2.05])
plt.ylim([1-0.05,len(group_number)+.05])
plt.xlabel(r"$J_R/J_L$",fontsize=20)
plt.ylabel(r"c",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig2_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
# n1, n2 = v_list.shape
# plt.figure(figsize=(4,4))
# plt.imshow(v_list)    
# plt.xlabel(r"$J_1$",fontsize=20)
# plt.ylabel(r"$J_2$",fontsize=20, rotation=0, horizontalalignment='right')
# plt.xticks([0, n1/2, n1-1],[r"0", "0.5", r"1"],fontsize=20)
# plt.yticks([0, n2/2, n2-1],[r"0", "0.5", r"1"], fontsize=20)

# # cmap = plt.cm.rainbow
# # norm = matplotlib.colors.BoundaryNorm(np.arange(-2.5, 3, 1), cmap.N)
# cb = plt.colorbar(ticks=range(len(center_indices)+1), fraction=0.046, pad=0.04)
# cb.ax.tick_params(labelsize=18)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # 1D Twisted band (point gap)

# %%
name =  "1D_Twisted_Winding"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig2_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
kappa2s = np.linspace(0.001,3, len(v_list))

plt.figure(figsize=(3,3))
plt.plot(kappa2s, v_list,'-o')
plt.xticks([0, 1, 2, 3],fontsize=20)
plt.yticks(range(1, len(group_number)+1),fontsize=20)
plt.xlim([-0.05, 3.05])
plt.ylim([1-0.05,len(group_number)+.05])
plt.xlabel(r"$\kappa_2/\kappa_1$",fontsize=20)
plt.ylabel(r"c",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig2_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %% [markdown]
# # 1D loss-and-gain induced (point gap)

# %%
name =  "1D_RM"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig2_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
ldas = np.linspace(0.001,3, len(v_list))

plt.figure(figsize=(3,3))
plt.plot(ldas, v_list,'-o')
plt.xticks([0, 1, 2, 3],fontsize=20)
plt.yticks(range(1, len(group_number)+1),fontsize=20)
plt.xlim([-0.05, 3.05])
plt.ylim([1-0.05,len(group_number)+.05])
plt.xlabel(r"$\tau$",fontsize=20)
plt.ylabel(r"c",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig2_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %% [markdown]
# # 1D SSH (point gap)

# %% [markdown]
# # 1D SSH (real line gap)

# %%
name =  "1D_SSH_real"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig3_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
n1, n2 = v_list.shape
plt.figure(figsize=(3,3))
plt.imshow(np.transpose(v_list), origin='lower',extent = [0,n1,0,n2])
plt.xlabel(r"$t_1$",fontsize=20)
plt.ylabel(r"$\gamma$",fontsize=20,rotation=0,horizontalalignment='right')
plt.xticks([0, n1/2, n1-1],[r"0", "1.5", r"3"],fontsize=20)
plt.yticks([0, n2/2, n2-1],[r"0", "1.5", r"3"], fontsize=20)

cb = plt.colorbar(ticks=range(len(center_indices)+1), fraction=0.046, pad=0.04)
cb.ax.tick_params(labelsize=18)

#plt.tight_layout()
plt.savefig('fig3_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %% [markdown]
# # 1D loss-and-gain induced (real line gap)

# %%
name =  "1D_loss_gain_real"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig3_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
n1, n2 = v_list.shape

plt.figure(figsize=(3,3))
plt.imshow(np.transpose(v_list), origin='lower',extent = [0,n1,0,n2])
plt.xlabel(r"$g_1$",fontsize=20)
plt.ylabel(r"$g_2$",fontsize=20, rotation=0, horizontalalignment='right')
plt.xticks([0, n1/2, n1-1],[r"-3", r"0", r"3"],fontsize=20)
plt.yticks([0, n2/2, n2-1],[r"-3", r"0", r"3"], fontsize=20)

cb = plt.colorbar(ticks=range(len(center_indices)+1), fraction=0.046, pad=0.04)
cb.ax.tick_params(labelsize=18)

#plt.tight_layout()
plt.savefig('fig3_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %% [markdown]
# # 1D non-reciprocal induced (real line gap)

# %%
name =  "1D_nonreciprocal_real"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig3_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
n1 = len(v_list)

varepsilons = np.linspace(0.001,2,n1)

plt.figure(figsize=(3,3))
plt.plot(varepsilons, v_list,'-o')
plt.xticks([0, 1, 2],fontsize=20)
plt.yticks(range(1, len(group_number)+1),fontsize=20)
plt.xlim([-0.05, 2.05])
plt.ylim([1-0.05,len(group_number)+.05])
plt.xlabel(r"$\varepsilon$",fontsize=20)
plt.ylabel(r"c",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig3_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %% [markdown]
# # 2D non-Hermitian Chern bands

# %%
name =  "2D_Chern_real"
center_indices, group_number = load_data("fig2_{0}_group_number.h5".format(name))
v_list = load_data_M("fig2_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig3_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
n1, n2 = v_list.shape

plt.figure(figsize=(3,3))
plt.imshow(np.transpose(v_list), origin='lower',extent = [0,n1,0,n2])
plt.xlabel(r"$m$",fontsize=20)
plt.ylabel(r"$\gamma$",fontsize=20, rotation=0, horizontalalignment='right')
plt.xticks([0, n1/2, n1-1],[r"1", r"2", r"3"],fontsize=20)
plt.yticks([0, n2/2, n2-1],[r"0", r"0.25", r"0.5"], fontsize=20)

cb = plt.colorbar(ticks=range(len(center_indices)+1), fraction=0.046, pad=0.04)
cb.ax.tick_params(labelsize=18)

#plt.tight_layout()
plt.savefig('fig3_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()

# %% [markdown]
# # 2D Mobius (real line-gap)

# %%
name =  "2D_Mobius_real"
center_indices, group_number = load_data("fig3_{0}_group_number.h5".format(name))
v_list = load_data_M("fig3_{0}_phase_diagram.h5".format(name))

plt.figure(figsize=(3,3))
plt.bar(np.arange(len(group_number))+1, group_number)
plt.xlim([0.5,len(group_number)+0.5])
plt.xticks(list(range(1,len(group_number)+1)),fontsize=20)
plt.ylim([0, np.max(group_number)*1.1])
plt.yticks([0, int(np.max(group_number)/2), int(np.max(group_number))],fontsize=20)
plt.xlabel(r"$c$",fontsize=20)
plt.ylabel(r"$M$",fontsize=20,rotation=0,horizontalalignment='right')

#plt.tight_layout()
plt.savefig('fig3_{0}_group_number.svg'.format(name), bbox_inches="tight")
plt.show()

# %%
n1, n2 = v_list.shape

plt.figure(figsize=(3,3))
plt.imshow(np.transpose(v_list), origin='lower',extent = [0,n1,0,n2])
plt.xlabel(r"$t_1$",fontsize=20)
plt.ylabel(r"$\gamma$",fontsize=20,rotation=0,horizontalalignment='right')
plt.xticks([0, n1/2, n1-1],[r"0", "1", r"2"],fontsize=20)
plt.yticks([0, n2/2, n2-1],[r"0", "1", r"2"], fontsize=20)

cb = plt.colorbar(ticks=range(len(center_indices)+1), fraction=0.046, pad=0.04)
cb.ax.tick_params(labelsize=18)

#plt.tight_layout()
plt.savefig('fig3_{0}_phase_diagram.svg'.format(name), bbox_inches="tight")
plt.show()
